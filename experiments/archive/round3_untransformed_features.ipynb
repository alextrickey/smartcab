# %%
# Import the visualization code
import visuals as vs

# Pretty display for notebooks
# %matplotlib inline

# %% [markdown]
# ## Compare Decay Rate Types (Transformed Features)

# %% [markdown]
# ### Linear - Average Reliability=0.85

# %%
#Linear, alpha=0.5, seed 1
vs.plot_trials('sim_improved-learning.csv')

# %%
#Linear, alpha=0.5, seed 2
vs.plot_trials('sim_improved-learning.csv')

# %%
#Linear, alpha=0.5, seed 3
vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### Exponential - Unsafe

# %%
#Exponential, alpha=0.5, seed 1
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.5, seed 2
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.5, seed 3
vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### Rational (Linear Denominator) - Average Reliability=0.957

# %%
#Rational (Linear), alpha=0.5, seed 1
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rational (Linear), alpha=0.5, seed 2
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rational (Linear), alpha=0.5, seed 3
vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### Rational (Polynomial Denominator) - Unsafe

# %%
#Rational (Polynomial), alpha=0.5, seed 1
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rational (Polynomial), alpha=0.5, seed 2
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rational (Polynomial), alpha=0.5, seed 3
vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### Logistic - Unsafe

# %%
#Logistic, alpha=0.5, seed 1
vs.plot_trials('sim_improved-learning.csv')

# %%
#Logistic, alpha=0.5, seed 2
vs.plot_trials('sim_improved-learning.csv')

# %%
#Logistic, alpha=0.5, seed 3
vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ## --------------------------------

# %% [markdown]
# ## Examine Rational Decay (Linear Denominator)

# %% [markdown]
# ### N = 80 -- UNSAFE

# %%
#Logistic, alpha=0.5, seed 3
vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### N = 100 -- average reliabiltiy=95.7

# %% [markdown]
# ### N = 120 -- average reliabiltiy=

# %%
#Logistic, alpha=0.5, seed 1
vs.plot_trials('sim_improved-learning.csv')

# %%
#Logistic, alpha=0.5, seed 2
vs.plot_trials('sim_improved-learning.csv')

# %%
#Logistic, alpha=0.5, seed 3
vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ## --------------------------------

# %% [markdown]
# ## Tune alpha for N=100

# %% [markdown]
# ### Alpha = 0.9 -- UNSAFE

# %%
#Rat-Lin, alpha=0.9, seed 1
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rat-Lin, alpha=0.9, seed 2
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rat-Lin, alpha=0.9, seed 3
vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### Alpha = 0.8 -- Rel=89.0

# %%
#Rat-Lin, alpha=0.8, seed 1
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rat-Lin, alpha=0.8, seed 2
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rat-Lin, alpha=0.8, seed 3
vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### Alpha = 0.7

# %%
#Rat-Lin, alpha=0.7, seed 1
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rat-Lin, alpha=0.7, seed 2
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rat-Lin, alpha=0.7, seed 3
vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### Alpha = 0.6

# %%
#Rat-Lin, alpha=0.6, seed 1
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rat-Lin, alpha=0.6, seed 2
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rat-Lin, alpha=0.6, seed 3
vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### Alpha = 0.5

# %%
#Rat-Lin, alpha=0.5, seed 1
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rat-Lin, alpha=0.5, seed 2
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rat-Lin, alpha=0.5, seed 3
vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### Alpha = 0.4

# %% [markdown]
# ### Alpha = 0.3
