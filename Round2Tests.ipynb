# %%
# Import the visualization code
import visuals as vs

# Pretty display for notebooks
# %matplotlib inline

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#e = 1/sqrt(t)

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#e = 1.0 - 1.0/(1.0 + math.exp(-0.2*(self.trial - 100.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#e = 1.0 - 1.0/(1.0 + math.exp(-0.1*(self.trial - 100.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#e = 1.0 - 1.0/(1.0 + math.exp(-0.05*(self.trial - 100.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#e = 1.0 - 1.0/(1.0 + math.exp(-0.05*(self.trial - 100.0))) -- alpha = 0.8

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.08*(self.trial - 60.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0/(self.trial)**1.5

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.08*(self.trial - 60.0))) -- one less feature

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 if self.trial < 99 else 0

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 0.8 - 0.8/(1.0 + math.exp(-0.1*(self.trial - 60.0)))

# %% [markdown]
# ## ---------------------------

# %%
#Linear 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Linear 
vs.plot_trials('sim_improved-learning.csv')
# Alternate Seed

# %%
#Exponential 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential 
vs.plot_trials('sim_improved-learning.csv')
#Alternate Seed

# %%
#Rational (Linear Denominator) 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rational (Linear Denominator) 
vs.plot_trials('sim_improved-learning.csv')
#Alternate Seed

# %%
#Rational (Polynomial Denominator) 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rational (Polynomial Denominator) 
vs.plot_trials('sim_improved-learning.csv')
#Alternate Seed
#consider smaller tol for this one...

# %%
#Logistic
vs.plot_trials('sim_improved-learning.csv')

# %%
#Logistic
vs.plot_trials('sim_improved-learning.csv')
#Alternate Seed
