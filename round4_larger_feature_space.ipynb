# %%
# Import the visualization code
import visuals as vs

# Pretty display for notebooks
# %matplotlib inline

# %% [markdown]
# ## Compare Decay Rate Types (Transformed Features)

# %% [markdown]
# ### Linear - Average Reliability=0.820

# %%
#Linear, alpha=0.5, seed 1
vs.plot_trials('sim_improved-learning.csv')

# %%
#Linear, alpha=0.5, seed 2
vs.plot_trials('sim_improved-learning.csv')

# %%
#Linear, alpha=0.5, seed 3
vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### Exponential - Average Reliability=0.913

# %%
#Exponential, alpha=0.5, seed 1
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.5, seed 2
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.5, seed 3
#vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### Rational (Linear Denominator) - Average Reliability=0.877

# %%
#Rational (Linear), alpha=0.5, seed 1
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Rational (Linear), alpha=0.5, seed 2
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Rational (Linear), alpha=0.5, seed 3
#vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### Rational (Polynomial Denominator) - Average Reliability=0.917 (high variability)

# %%
#Rational (Polynomial), alpha=0.5, seed 1
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Rational (Polynomial), alpha=0.5, seed 2
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Rational (Polynomial), alpha=0.5, seed 3
#vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### Logistic - Average Reliability=0.840

# %%
#Logistic, alpha=0.5, seed 1
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Logistic, alpha=0.5, seed 2
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Logistic, alpha=0.5, seed 3
#vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ## Tune Learning Rate for Exponential

# %% [markdown]
# ### alpha = 0.9 -- average reliability = 86.7

# %%
#Exponential, alpha=0.9, seed 1
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.9, seed 2
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.9, seed 3
#vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### alpha = 0.7 -- average reliability = 92.3

# %%
#Exponential, alpha=0.7, seed 1
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.7, seed 2
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.7, seed 3
#vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### alpha = 0.6

# %%
#Exponential, alpha=0.6, seed 1
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.6, seed 2
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.6, seed 3
vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### alpha = 0.4 -- average reliability = 93.3

# %%
#Exponential, alpha=0.4, seed 1
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.4, seed 2
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.4, seed 3
#vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ## Tune N-Trials for Exponential

# %% [markdown]
# ### N = 50 -- average reliability = 90.3

# %%
#Exponential, alpha=0.5, seed 1, n=50
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.5, seed 2, n=50
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.5, seed 3, n=50
#vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### N = 60

# %%
#Exponential, alpha=0.5, seed 1, n=60
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.5, seed 2, n=60
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.5, seed 3, n=60
vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### N = 70 -- average reliability = 84.7

# %%
#Exponential, alpha=0.5, seed 1, n=70
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.5, seed 2, n=70
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.5, seed 3, n=70
#vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### N = 80

# %% [markdown]
# ### N = 90 -- average reliability  = 89.0

# %%
#Exponential, alpha=0.5, seed 1, n=90
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.5, seed 2, n=90
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.5, seed 3, n=90
#vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### N = 100

# %% [markdown]
# ### N = 110

# %%
#Exponential, alpha=0.5, seed 1, n=110
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.5, seed 2, n=110
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.5, seed 3, n=110
#vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ## Experiment with Tolerance

# %%
#Exponential, alpha=0.5, seed 3, n=110, HIGH TOL (0.1)
#vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential, alpha=0.5, seed 3, n=110, LOW TOL (0.01)
#vs.plot_trials('sim_improved-learning.csv')
