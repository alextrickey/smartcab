# %% [markdown]
# ## Run One Set of 30 Trials

# %%
# Import the visualization code, other libs
import visuals as vs
import matplotlib.pyplot as plt
import numpy as np

# Pretty display for notebooks
# %matplotlib inline

# %%
# %%capture
# !python smartcab/agent.py

# %%
#1
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#2
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#3
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#4
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#5
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#6
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#7
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#8
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#9
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#10
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#11
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#12
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#13
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#14
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#15
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#16
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#17
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#18
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#19
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#20
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#21
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#22
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#23
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#24
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#25
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#26
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#27
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#28
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#29
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
# %%capture
# !python smartcab/agent.py

# %%
#30
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %%
#Tally
95, 99, 100, 93, 97, 99,  95, 99, 100, 97, 
95, 97,  98, 98, 99, 96, 95, 100, 96,  98, 
97, 98, 95,  99, 97, 94, 98, 100, 99,  99
# Out:
# (97, 98, 95, 99, 97, 94, 98, 100, 99, 99)
