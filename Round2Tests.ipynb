# %%
# Import the visualization code
import visuals as vs

# Pretty display for notebooks
# %matplotlib inline

# %%
#what if it runs a really long time?
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#e = 1/sqrt(t)

# %%
#What if it just experiments a ton?
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 if self.trial < 99 else 0

# %% [markdown]
# ## ---------------------------

# %%
#Linear 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Linear 
vs.plot_trials('sim_improved-learning.csv')
# Alternate Seed

# %%
#Exponential 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential 
vs.plot_trials('sim_improved-learning.csv')
#Alternate Seed

# %%
#Rational (Linear Denominator) 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rational (Linear Denominator) 
vs.plot_trials('sim_improved-learning.csv')
#Alternate Seed

# %%
#Rational (Polynomial Denominator) 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Rational (Polynomial Denominator) 
vs.plot_trials('sim_improved-learning.csv')
#Alternate Seed
#consider smaller tol for this one...

# %%
#Logistic
vs.plot_trials('sim_improved-learning.csv')

# %%
#Logistic
vs.plot_trials('sim_improved-learning.csv')
#Alternate Seed

# %% [markdown]
# ### Look at various alpha levels for Exponential Exploration Factor Decay Model

# %%
#Exponential; alpha = 0.5; 100 trials
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.6; 100 trials
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.4; 100 trials
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.4; 100 trials; seed 2
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.4; 80 trials; seed 2; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.8; 100 trials; seed 2; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 1; 1000 trials; seed 1; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.9; 1000 trials; seed 1; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.8; 1000 trials; seed 1; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.7; 1000 trials; seed 1; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.6; 1000 trials; seed 1; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.5; 1000 trials; seed 1; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.4; 1000 trials; seed 1; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.3; 1000 trials; seed 1; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.2; 1000 trials; seed 1; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.1; 1000 trials; seed 1; 
vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ## ------------------------------------------

# %%
#Exponential; alpha = 0.9; 1000 trials; seed 3; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.8; 1000 trials; seed 3; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.7; 1000 trials; seed 3; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.6; 1000 trials; seed 3; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.5; 1000 trials; seed 3; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.4; 1000 trials; seed 3; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.3; 1000 trials; seed 3; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.2; 1000 trials; seed 3; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.1; 1000 trials; seed 3; 
vs.plot_trials('sim_improved-learning.csv')

# %%
#Exponential; alpha = 0.4; 10 trials; seed 3; 
vs.plot_trials('sim_improved-learning.csv')
