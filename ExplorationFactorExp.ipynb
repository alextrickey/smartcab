# %%
# Import the visualization code
import visuals as vs

# Pretty display for notebooks
# %matplotlib inline

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
# linear 0.05

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
# linear 0.0125

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
# (0.5)^t

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
# (0.9)^t

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
# (0.4)^t

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
# (0.7)^t

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = math.exp(-self.trial * 0.5)

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = math.exp(-self.trial * 0.2)

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = -1.0 / (1.0 + math.exp(-(self.trial - 10.0)))

# %%
import math
for i in range(0,20):
    print i, 1.0 -1.0 / (1.0 + math.exp(-(i - 10.0)))
# Out:
# 0 0.999954602131
# 1 0.999876605424
# 2 0.99966464987
# 3 0.999088948806
# 4 0.997527376843
# 5 0.993307149076
# 6 0.982013790038
# 7 0.952574126822
# 8 0.880797077978
# 9 0.73105857863
# 10 0.5
# 11 0.26894142137
# 12 0.119202922022
# 13 0.0474258731776
# 14 0.0179862099621
# 15 0.00669285092428
# 16 0.00247262315663
# 17 0.000911051194401
# 18 0.000335350130466
# 19 0.000123394575986

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-(self.trial - 10.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-(self.trial - 10.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.8*(self.trial - 8.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.8*(self.trial - 10.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-(self.trial - 10.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-(self.trial - 10.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-(self.trial - 15.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-(self.trial - 11.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-(self.trial - 5.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-(self.trial - 5.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-(self.trial - 5.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.5*(self.trial - 5.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.5*(self.trial - 5.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.7*(self.trial - 5.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.7*(self.trial - 5.0)))
#!!Same as above different seed

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.4*(self.trial - 5.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.4*(self.trial - 10.0)))

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.2*(self.trial - 10.0)))

# %%
### Adds left input feature
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.2*(self.trial - 10.0)))

# %%
### Adds left input feature
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.7*(self.trial - 10.0)))

# %%
# With additional feature
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-(self.trial - 5.0)))

# %%
# Still with extra feature
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#slow linear

# %%
#Still with extra feature
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.7(self.trial - 15.0)))

# %%
#Still with extra feature
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.4(self.trial - 15.0)))

# %%
#Still with extra feature
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.5(self.trial - 14.0)))

# %%
#Still with extra feature
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.2(self.trial - 20.0)))

# %%
#Still with extra feature
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.2(self.trial - 20.0)))
#tol=0.001

# %%
#Still with extra feature
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#self.epsilon = 1.0 - 1.0/(1.0 + math.exp(-0.2(self.trial - 20.0)))
#tol=0.001

# %%
#Still with extra feature
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#even slower linear

# %%
#without extra feature
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')
#even slower linear
