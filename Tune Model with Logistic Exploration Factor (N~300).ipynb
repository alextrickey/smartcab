# %%
# Import the visualization code
import visuals as vs

# Pretty display for notebooks
# %matplotlib inline

# %% [markdown]
# ### Try lower trial number and tolerance
#
# - self.n = 250
# - self.epsilon_val_at_n = 0.001
# - selt.tolerance = 0.0001
# - self.exploration_type = 'logistic'
# - alpha = 0.5

# %%
vs.plot_trials('sim_improved-learning.csv')
#1

# %%
vs.plot_trials('sim_improved-learning.csv')
#2

# %%
vs.plot_trials('sim_improved-learning.csv')
#3

# %%
vs.plot_trials('sim_improved-learning.csv')
#4

# %%
vs.plot_trials('sim_improved-learning.csv')
#5

# %% [markdown]
# ### Try trial number = 300, tolerance 0.001, but raise alpha
#
# - self.n = 300
# - self.epsilon_val_at_n = 0.001
# - selt.tolerance = 0.001
# - self.exploration_type = 'logistic'
# - alpha = 0.7

# %%
vs.plot_trials('sim_improved-learning.csv')
#1

# %%
vs.plot_trials('sim_improved-learning.csv')
#2

# %%
vs.plot_trials('sim_improved-learning.csv')
#3

# %%
vs.plot_trials('sim_improved-learning.csv')
#4

# %%
vs.plot_trials('sim_improved-learning.csv')
#5

# %%
vs.plot_trials('sim_improved-learning.csv')
#6

# %%
vs.plot_trials('sim_improved-learning.csv')
#7

# %%
vs.plot_trials('sim_improved-learning.csv')
#8

# %%
vs.plot_trials('sim_improved-learning.csv')
#9

# %%
vs.plot_trials('sim_improved-learning.csv')
#10

# %% [markdown]
# ### Try alpha = 0.8
#
# - self.n = 250
# - self.epsilon_val_at_n = 0.001
# - selt.tolerance = 0.0001
# - self.exploration_type = 'logistic'
# - alpha = 0.8

# %%
vs.plot_trials('sim_improved-learning.csv')
#1

# %%
vs.plot_trials('sim_improved-learning.csv')
#2

# %%
vs.plot_trials('sim_improved-learning.csv')
#3

# %%
vs.plot_trials('sim_improved-learning.csv')
#4

# %%
vs.plot_trials('sim_improved-learning.csv')
#5

# %%
vs.plot_trials('sim_improved-learning.csv')
#6

# %%
vs.plot_trials('sim_improved-learning.csv')
#7

# %%
vs.plot_trials('sim_improved-learning.csv')
#8

# %%
vs.plot_trials('sim_improved-learning.csv')
#9

# %%
vs.plot_trials('sim_improved-learning.csv')
#10
